# %%
import pandas as pd

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7fb78ddb6dc5> in <module>()
# ----> 1 fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')
#
# NameError: name 'plt' is not defined

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# définiton d'un style de type grille sous fond blanc
sns.set(style="whitegrid")

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
tips = sns.load_dataset("tips")

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig_dims = (10, 10)
fig, ax1 = plt.subplots(figsize=fig_dims)

sns.boxplot(x="total_bill", ax=ax1, data= tips)
plt.show()

# %%
fig_dims = (20, 15)
fig, ax2 = plt.subplots(figsize=fig_dims)

sns.boxplot(x="day", y="total_bill", ax=ax2, data=tips)
plt.show()

# %%
fig_dims = (20, 10)
fig, ax3 = plt.subplots(figsize=fig_dims)

sns.boxplot(x="day", y="total_bill", hue="smoker", ax=ax3,
                 data=tips, palette="Set3")

plt.show()

# %%
iris = sns.load_dataset("iris")

iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
fig_dims = (10, 20)
fig, ax4 = plt.subplots(figsize=fig_dims)

sns.boxplot(x='species', y='petal_length', ax=ax4, data=iris)

plt.show()
