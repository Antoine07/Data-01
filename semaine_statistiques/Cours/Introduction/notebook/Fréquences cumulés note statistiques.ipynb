# %%
import pandas as pd

notes = pd.read_csv('./data/notes_statistiques.csv')

notes
# Out:
#     Notes examen de statistiques  Effectifs
# 0                              0          0
# 1                              1          0
# 2                              2          2
# 3                              3          0
# 4                              4          1
# 5                              5          0
# 6                              6          1
# 7                              7          0
# 8                              8          1
# 9                              9          1
# 10                            10          7
# 11                            11          2
# 12                            12          3
# 13                            13          1
# 14                            14          1
# 15                            15          1
# 16                            16          2
# 17                            17          0
# 18                            18          1
# 19                            19          0
# ...

# %%
notes['Frequence'] = notes[['Effectifs']] / notes['Effectifs'].sum()
notes = notes.rename(columns={'Notes examen de statistiques': 'Notes'})

notes.head()
# Out:
#    Notes  Effectifs  Frequence
# 0      0          0       0.00
# 1      1          0       0.00
# 2      2          2       0.08
# 3      3          0       0.00
# 4      4          1       0.04

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

fig = plt.figure()

width = 0.05

plt.bar(notes['Notes'].values, notes['Effectifs'].values, width, color='b' )

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
notes = notes.rename(columns = {'Notes examen de statistiques' : 'Notes'})

notes
# Out:
#     Notes  Effectifs  Frequence
# 0       0          0       0.00
# 1       1          0       0.00
# 2       2          2       0.08
# 3       3          0       0.00
# 4       4          1       0.04
# 5       5          0       0.00
# 6       6          1       0.04
# 7       7          0       0.00
# 8       8          1       0.04
# 9       9          1       0.04
# 10     10          7       0.28
# 11     11          2       0.08
# 12     12          3       0.12
# 13     13          1       0.04
# 14     14          1       0.04
# 15     15          1       0.04
# 16     16          2       0.08
# 17     17          0       0.00
# 18     18          1       0.04
# 19     19          0       0.00
# 20     20          1       0.04

# %%
notes['notes_bin'] = pd.qantiles(x=notes['Notes'], bins=[0, 4, 8, 10, 12, 14, 18, 21])
print(notes)

grouped = notes.groupby('notes_bin')

dfNotes = grouped[['Effectifs']].sum()

dfNotes['Frequences'] = dfNotes['Effectifs'] / dfNotes['Effectifs'].sum()

dfNotes.round(2)
# Out:
#     Notes  Effectifs  Frequence notes_bin
# 0       0          0       0.00       NaN
# 1       1          0       0.00    (0, 4]
# 2       2          2       0.08    (0, 4]
# 3       3          0       0.00    (0, 4]
# 4       4          1       0.04    (0, 4]
# 5       5          0       0.00    (4, 8]
# 6       6          1       0.04    (4, 8]
# 7       7          0       0.00    (4, 8]
# 8       8          1       0.04    (4, 8]
# 9       9          1       0.04   (8, 10]
# 10     10          7       0.28   (8, 10]
# 11     11          2       0.08  (10, 12]
# 12     12          3       0.12  (10, 12]
# 13     13          1       0.04  (12, 14]
# 14     14          1       0.04  (12, 14]
# 15     15          1       0.04  (14, 18]
# 16     16          2       0.08  (14, 18]
# 17     17          0       0.00  (14, 18]
# 18     18          1       0.04  (14, 18]
# 19     19          0       0.00  (18, 21]
# 20     20          1       0.04  (18, 21]
# ...

# %%
# Fermeture de l'objet matplotlib
plt.close()

# %%
# %matplotlib notebook
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks", color_codes=True)

sns.catplot(x="Effectifs", y ='Frequences', kind="bar", palette="ch:.25", data=dfNotes);
# Out:
# <img src="data:image/png;base64,..." width="500">
